# %% [markdown]
# importing

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load the dataset as a dataframe.

# %%
df = pd.read_csv("Weather Dataset.csv")
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 3775  2006-08-11 02:00:00.000 +0200  Mostly Cloudy        rain
# 3776  2006-12-26 12:00:00.000 +0100  Partly Cloudy        rain
# 3777  2006-12-19 20:00:00.000 +0100       Overcast        rain
# 3778  2006-12-10 11:00:00.000 +0100  Partly Cloudy        rain
# 3779  2006-12-10 15:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# Clean and preprocess the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3780 entries, 0 to 3779
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            3780 non-null   object
#  1   Summary                   3780 non-null   object
#  2   Precip Type               3780 non-null   object
#  3   Temperature (C)           3780 non-null   float64
#  4   Apparent Temperature (C)  3780 non-null   float64
#  5   Humidity                  3780 non-null   float64
#  6   Wind Speed (km/h)         3780 non-null   float64
#  7   Wind Bearing (degrees)    3780 non-null   float64
#  8   Visibility (km)           3780 non-null   float64
#  9   Loud Cover                3780 non-null   float64
#  10  Pressure (millibars)      3780 non-null   float64
#  11  Daily Summary             3780 non-null   object
# dtypes: float64(8), object(4)
# memory usage: 354.5+ KB

# %%
df[df["Temperature (C)"] < -273]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
df[df["Temperature (C)"] > 273]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
y = df['Temperature (C)'].to_numpy()
average = np.average(y)
df.replace(-2000, average, inplace= True)

# %%
df[df["Humidity"]> 1]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
df[df["Humidity"]< 0]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
z = df["Humidity"].to_numpy()
df.drop(index=[0])
df.drop(labels = 3247, axis =0, inplace= True)

# %%
dup = df.duplicated().sum()
dup
# Out:
# np.int64(1259)

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 2515  2006-02-20 19:00:00.000 +0100  Partly Cloudy        rain
# 2516  2006-02-20 20:00:00.000 +0100  Mostly Cloudy        rain
# 2517  2006-02-20 21:00:00.000 +0100  Mostly Cloudy        rain
# 2518  2006-02-20 22:00:00.000 +0100  Mostly Cloudy        rain
# 2519  2006-02-20 23:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.drop(labels ="Loud Cover", axis =1, inplace= True)

# %%
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 2515  2006-02-20 19:00:00.000 +0100  Partly Cloudy        rain
# 2516  2006-02-20 20:00:00.000 +0100  Mostly Cloudy        rain
# 2517  2006-02-20 21:00:00.000 +0100  Mostly Cloudy        rain
# 2518  2006-02-20 22:00:00.000 +0100  Mostly Cloudy        rain
# 2519  2006-02-20 23:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# import library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# plot tempreture over time

# %%
x = df['Formatted Date'].to_numpy()
y = df['Temperature (C)'].to_numpy()

plt.plot(x, y)
plt.xlabel("temprature")
plt.ylabel("time")
plt.title("plot tempreture over time")
# Out:
# Text(0.5, 1.0, 'plot tempreture over time')

# %% [markdown]
# histogram

# %%
plt.hist(y, edgecolor = "black")
plt.show()

# %% [markdown]
# Plot a scatter plot of temperature vs. humidity.

# %%
z = df["Humidity"].to_numpy()
plt.scatter(y, z, s = 2)

# %%
import seaborn as sns

# %%
df["Formatted Date"] = pd.to_datetime(df["Formatted Date"], utc =True)

df["Formatted Date"] = (df["Formatted Date"] -pd.to_datetime("2006-04-01 16:00:00.000 +0200"))
pd.Timedelta("1D")
df

# %%
df
# Out:
#          Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     -1 days +08:00:00  Partly Cloudy        rain         9.472222
# 1     -1 days +09:00:00  Partly Cloudy        rain         9.355556
# 2     -1 days +10:00:00  Mostly Cloudy        rain         9.377778
# 3     -1 days +11:00:00  Partly Cloudy        rain         8.288889
# 4     -1 days +12:00:00  Mostly Cloudy        rain         8.755556
# ...                 ...            ...         ...              ...
# 2515 -40 days +04:00:00  Partly Cloudy        rain         9.094444
# 2516 -40 days +05:00:00  Mostly Cloudy        rain         8.905556
# 2517 -40 days +06:00:00  Mostly Cloudy        rain         8.883333
# 2518 -40 days +07:00:00  Mostly Cloudy        rain         8.266667
# 2519 -40 days +08:00:00  Mostly Cloudy        rain         7.316667
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     7.388889      0.89            14.1197
# ...

# %%
df_numeric =df.select_dtypes(include="number")
df_numeric =df_numeric.corr()
sns.heatmap(df_numeric, annot= True, linewidths= 1, linecolor= "black")
# Out:
# <Axes: >

# %% [markdown]
# -there are positive nums(direct relation) , negative nums(iinverse relation) and when it is close to zero mean that there is a weak relation between varibales
# -the colors also express the same thing as showing in the figure
# -the main diagonal = 1 because it is the relation between the same varible
